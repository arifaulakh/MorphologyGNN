# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('metadata_scala.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Number', 'Cell', 'Slice', 'Date', 'Sample', 'blah',
#        'cell_num', 'donor_id', 'Mouse date of birth', 'age', 'biological_sex',
#        'genotype', 'Targeted layer', 'Inferred layer', 'Cre', 'Exon reads',
#        'Intron reads', 'Intergenic reads', 'Sequencing batch',
#        'Number of genes detected', 'RNA family', 'RNA type',
#        'RNA type confidence', 'RNA type top-3', 'ALM/VISp top-3',
#        'top_cluster_string', 'top_alm_visp_cluster', 'subclass',
#        'corresponding_AIT2.3.1_alias', 'layer', 'type', 'region',
#        'cluster_score_string', 'cluster_score_string_number', 'rest',
#        'top_alm_visp_subclass', 'Length (bp)', 'Yield (pg/µl)', 'User',
#        'hold_time', 'Soma depth (µm)', 'Soma depth (4x)',
#        'Cortical thickness (4x)', 'Cortical thickness (µm)', 'Traced',
#        'Exclusion reasons', 'X1', 'major_type', 'contam_type', 'marker_sum',
#        'marker_sum_norm', 'contam_sum', 'quality_score', 'Glutamatergic',
# ...

# %%
df.drop(columns= ['Unnamed: 0'])
# Out:
#       Number               Cell             Slice        Date    Sample
# 0          1  20171204_sample_2  20171204_slice_2  2017-12-04  sample 2  \
# 1          2  20171204_sample_4  20171204_slice_4  2017-12-04  sample 4
# 2          3  20171204_sample_5  20171204_slice_5  2017-12-04  sample 5
# 3          4  20171204_sample_6  20171204_slice_6  2017-12-04  sample 6
# 4          5  20171207_sample_1  20171207_slice_1  2017-12-07  sample 1
# ...      ...                ...               ...         ...       ...
# 1097    1309  20191107_sample_4  20191107_slice_4  2019-11-07  Sample 4
# 1098    1313  20191114_sample_1  20191114_slice_1  2019-11-14  Sample 1
# 1099    1316  20191114_sample_4  20191114_slice_3  2019-11-14  Sample 4
# 1100    1321  20200106_sample_1  20200106_slice_1  2020-01-06  Sample 1
# 1101    1329  20200316_sample_3  20200316_slice_3  2020-03-16  Sample 3
#
#         blah  cell_num     donor_id Mouse date of birth  age  ...      VLMC
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Number', 'Cell', 'Slice', 'Date', 'Sample', 'blah',
#        'cell_num', 'donor_id', 'Mouse date of birth', 'age', 'biological_sex',
#        'genotype', 'Targeted layer', 'Inferred layer', 'Cre', 'Exon reads',
#        'Intron reads', 'Intergenic reads', 'Sequencing batch',
#        'Number of genes detected', 'RNA family', 'RNA type',
#        'RNA type confidence', 'RNA type top-3', 'ALM/VISp top-3',
#        'top_cluster_string', 'top_alm_visp_cluster', 'subclass',
#        'corresponding_AIT2.3.1_alias', 'layer', 'type', 'region',
#        'cluster_score_string', 'cluster_score_string_number', 'rest',
#        'top_alm_visp_subclass', 'Length (bp)', 'Yield (pg/µl)', 'User',
#        'hold_time', 'Soma depth (µm)', 'Soma depth (4x)',
#        'Cortical thickness (4x)', 'Cortical thickness (µm)', 'Traced',
#        'Exclusion reasons', 'X1', 'major_type', 'contam_type', 'marker_sum',
#        'marker_sum_norm', 'contam_sum', 'quality_score', 'Glutamatergic',
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  Number               Cell             Slice        Date
# 0           1       1  20171204_sample_2  20171204_slice_2  2017-12-04  \
# 1           2       2  20171204_sample_4  20171204_slice_4  2017-12-04
# 2           3       3  20171204_sample_5  20171204_slice_5  2017-12-04
# 3           4       4  20171204_sample_6  20171204_slice_6  2017-12-04
# 4           5       5  20171207_sample_1  20171207_slice_1  2017-12-07
#
#      Sample    blah  cell_num     donor_id Mouse date of birth  ...      VLMC
# 0  sample 2  sample         2  mouse_GTOKH          2017-10-29  ...  0.059878  \
# 1  sample 4  sample         4  mouse_GTOKH          2017-10-29  ...  0.089816
# 2  sample 5  sample         5  mouse_GTOKH          2017-10-29  ...  0.065343
# 3  sample 6  sample         6  mouse_GTOKH          2017-10-29  ...  0.066244
# 4  sample 1  sample         1  mouse_UGZSW          2017-09-18  ...  0.176707
#
#   QC_pass top_cluster_score depth_from_pia_um cell_count_per_donor
# ...
